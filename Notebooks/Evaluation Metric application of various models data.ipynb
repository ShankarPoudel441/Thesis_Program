# %%
#Import libraries:
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN

# %%
df=pd.read_csv("/home/spoudel/All_Thesis/Thesis_program/Data/shawnee/location_1/KMeans/cluster_predicted_pass_115.csv")
data_size=len(df)
df
# Out:
#      Unnamed: 0  Unnamed: 0.1                         timestamp  total_power  \
# 0             0             0  2023-01-16 17:24:39.120000+00:00   100.000000
# 1             1             1  2023-01-16 17:24:39.257000+00:00    30.908002
# 2             2             2  2023-01-16 17:24:39.384000+00:00    35.629787
# 3             3             3  2023-01-16 17:24:39.511000+00:00    16.531542
# 4             4             4  2023-01-16 17:24:39.638000+00:00    30.659669
# ..          ...           ...                               ...          ...
# 353         353           353  2023-01-16 17:25:24.165000+00:00    15.994001
# 354         354           354  2023-01-16 17:25:24.292000+00:00    39.097577
# 355         355           355  2023-01-16 17:25:24.419000+00:00    57.565264
# 356         356           356  2023-01-16 17:25:24.546000+00:00    77.731484
# 357         357           357  2023-01-16 17:25:24.673000+00:00    49.185083
#
# ...

# %%
X=np.array(df[["p0","p1","p2","p3","p4","p5","p6"]])
y=np.array(df["cluster"])

# %%
from sklearn.metrics import silhouette_score
#Higher Better
#[-1,1]
#Very near to zero, overlapping clusters
sihl = silhouette_score(X, y, metric="euclidean")
sihl
# Out:
# 0.034400918167766

# %%
from sklearn.metrics import calinski_harabasz_score
#Higher Better
calin = calinski_harabasz_score(X, y)
calin
# Out:
# 24.71265046761044

# %%
from sklearn.metrics import davies_bouldin_score
#Lower better
DB = davies_bouldin_score(X, y)
DB
# Out:
# 3.0883644121481657

# %%
def intrinsic_metrics(X,clusters):
    print("")
    sihl = silhouette_score(X, clusters, metric="euclidean")
    calin = calinski_harabasz_score(X, clusters)
    DB = davies_bouldin_score(X, clusters)
    print(f"sihl={sihl}\ncalin={calin}\nDB={DB}\n")
    return sihl,calin,DB

def intrinsic_metrics_betn_class(X,clusters,class1,class2):
    print("")
    sihl = silhouette_score(X, clusters, metric="euclidean")
    calin = calinski_harabasz_score(X, clusters)
    DB = davies_bouldin_score(X, clusters)
    print(f"sihl={sihl}\ncalin={calin}\nDB={DB}\n")
    return sihl,calin,DB

# %%
## 1 vs 3
df_KMean=pd.read_csv("/home/spoudel/All_Thesis/Thesis_program/Data/shawnee/location_1/Kmeans/cluster_predicted_pass_115.csv")

df_KMean[(df_KMean["cluster"]==1) |
                  (df_KMean["cluster"]==3)
                 ]
# df_KMean
# Out:
#      Unnamed: 0  Unnamed: 0.1                         timestamp  total_power  \
# 0             0             0  2023-01-16 17:24:39.120000+00:00   100.000000
# 10           10            10  2023-01-16 17:24:40.390000+00:00    64.015246
# 14           14            14  2023-01-16 17:24:40.907000+00:00    32.570440
# 16           16            16  2023-01-16 17:24:41.162000+00:00    40.853349
# 17           17            17  2023-01-16 17:24:41.289000+00:00    69.458750
# ..          ...           ...                               ...          ...
# 350         350           350  2023-01-16 17:25:23.784000+00:00    50.283046
# 351         351           351  2023-01-16 17:25:23.911000+00:00    88.400855
# 353         353           353  2023-01-16 17:25:24.165000+00:00    15.994001
# 354         354           354  2023-01-16 17:25:24.292000+00:00    39.097577
# 356         356           356  2023-01-16 17:25:24.546000+00:00    77.731484
#
# ...

# %%
print("Shawnee_1")
df_KMean=pd.read_csv("/home/spoudel/All_Thesis/Thesis_program/Data/shawnee/location_1/KMeans/cluster_predicted_pass_115.csv")
df_KMean_xy=df_KMean[["p0","p1","p2","p3","p4","p5","p6","cluster"]]
print("For Kmeans")

#1vs2
print("1vs2")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==0)|
                  (df_KMean_xy["cluster"]==1)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)


#1vs3
print("1vs3")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==0)|
                  (df_KMean_xy["cluster"]==2)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#1vs4
print("1vs4")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==0)|
                  (df_KMean_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#1vs5
print("1vs5")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==0)|
                  (df_KMean_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#2vs3
print("2vs3")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==1)|
                  (df_KMean_xy["cluster"]==2)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#2vs4
print("2vs4")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==1)|
                  (df_KMean_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#2vs5
print("2vs5")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==1)|
                  (df_KMean_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#3vs4
print("3vs4")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==2)|
                  (df_KMean_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#3vs5
print("3vs5")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==2)|
                  (df_KMean_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#4vs5
print("3vs5")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==3)|
                  (df_KMean_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)



df_GMM=pd.read_csv("/home/spoudel/All_Thesis/Thesis_program/Data/shawnee/location_1/GMM/cluster_predicted_pass_115.csv")
df_GMM_xy=df_GMM[["p0","p1","p2","p3","p4","p5","p6","cluster"]]
# y_GMM=np.array(df_GMM["cluster"])
print("For GMM")
#1vs2
print("1vs2")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==0)|
                  (df_GMM_xy["cluster"]==1)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#1vs3
print("1vs3")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==0)|
                  (df_GMM_xy["cluster"]==2)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#1vs4
print("1vs4")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==0)|
                  (df_GMM_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#1vs5
print("1vs5")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==0)|
                  (df_GMM_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)


#2vs3
print("2vs3")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==1)|
                  (df_GMM_xy["cluster"]==2)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#2vs4
print("2vs4")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==1)|
                  (df_GMM_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#2vs5
print("2vs5")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==1)|
                  (df_GMM_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#3vs4
print("3vs4")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==2)|
                  (df_GMM_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#3vs5
print("3vs5")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==2)|
                  (df_GMM_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#4vs5
print("4vs5")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==3)|
                  (df_GMM_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)
# Out:
# Shawnee_1
# For Kmeans
# 1vs2
# 117
# 358 117
#
# sihl=0.0818397512807107
# calin=8.578709856103814
# DB=3.0934606476182673
#
# 1vs3
# 156
# 358 156
#
# sihl=0.16111177035623145
# calin=22.40151835049119
# DB=1.9846093433431737
#
# 1vs4
# 121
# 358 121
#
# sihl=0.2472551526727436
# calin=37.8584652639722
# DB=1.4229708440163864
#
# 1vs5
# 57
# 358 57
#
# sihl=0.320518834099152
# calin=29.99508829595196
# DB=1.320051562967993
#
# 2vs3
# 211
# 358 211
#
# sihl=0.06782141475315892
# calin=15.481796910757156
# DB=3.416314836790415
#
# 2vs4
# 176
# 358 176
#
# sihl=0.19406192166021763
# calin=43.40789146925661
# DB=1.900611817160226
#
# 2vs5
# 112
# 358 112
#
# sihl=0.328051449900998
# calin=35.16682660501479
# DB=1.559916036800606
#
# 3vs4
# 215
# 358 215
#
# sihl=0.10684436497592686
# calin=24.189660644319193
# DB=2.8609412461651655
#
# 3vs5
# 151
# 358 151
#
# sihl=0.22117386871939188
# calin=18.409546664867463
# DB=2.2644919579956944
#
# 3vs5
# 116
# 358 116
#
# ...

# %%
print("shawnee_1")
KMean_home="/home/spoudel/All_Thesis/Thesis_program/Data/shawnee/location_1/KMeans/"
passes=["cluster_predicted_pass_115.csv",
       "cluster_predicted_pass_117.csv",
       "cluster_predicted_pass_118.csv",
       "cluster_predicted_pass_120.csv",
       "cluster_predicted_pass_121.csv"]
df_KMean=pd.concat([pd.read_csv(KMean_home+"/"+x) for x in passes],ignore_index=True)
df_KMean_xy=df_KMean[["p0","p1","p2","p3","p4","p5","p6","cluster"]]
print("For Kmeans")
#1vs2
print("1vs2")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==0)|
                  (df_KMean_xy["cluster"]==1)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)


#1vs3
print("1vs3")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==0)|
                  (df_KMean_xy["cluster"]==2)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#1vs4
print("1vs4")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==0)|
                  (df_KMean_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#1vs5
print("1vs5")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==0)|
                  (df_KMean_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#2vs3
print("2vs3")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==1)|
                  (df_KMean_xy["cluster"]==2)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#2vs4
print("2vs4")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==1)|
                  (df_KMean_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#2vs5
print("2vs5")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==1)|
                  (df_KMean_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#3vs4
print("3vs4")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==2)|
                  (df_KMean_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#3vs5
print("3vs5")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==2)|
                  (df_KMean_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#4vs5
print("3vs5")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==3)|
                  (df_KMean_xy["cluster"]==4)
                 ]
print(len(df_13))

X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

GMM_home="/home/spoudel/All_Thesis/Thesis_program/Data/shawnee/location_1/GMM"
passes=["cluster_predicted_pass_115.csv",
       "cluster_predicted_pass_117.csv",
       "cluster_predicted_pass_118.csv",
       "cluster_predicted_pass_120.csv",
       "cluster_predicted_pass_121.csv"]
df_GMM=pd.concat([pd.read_csv(GMM_home+"/"+x) for x in passes],ignore_index=True)
df_GMM_xy=df_GMM[["p0","p1","p2","p3","p4","p5","p6","cluster"]]
print("For GMM")
#1vs2
print("1vs2")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==0)|
                  (df_GMM_xy["cluster"]==1)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#1vs3
print("1vs3")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==0)|
                  (df_GMM_xy["cluster"]==2)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#1vs4
print("1vs4")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==0)|
                  (df_GMM_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#1vs5
print("1vs5")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==0)|
                  (df_GMM_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)


#2vs3
print("2vs3")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==1)|
                  (df_GMM_xy["cluster"]==2)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#2vs4
print("2vs4")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==1)|
                  (df_GMM_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#2vs5
print("2vs5")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==1)|
                  (df_GMM_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#3vs4
print("3vs4")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==2)|
                  (df_GMM_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#3vs5
print("3vs5")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==2)|
                  (df_GMM_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#4vs5
print("4vs5")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==3)|
                  (df_GMM_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)
# Out:
# shawnee_1
# For Kmeans
# 1vs2
# 790
# 1810 790
#
# sihl=0.08716414371315306
# calin=73.65917898895881
# DB=3.0810780687696524
#
# 1vs3
# 833
# 1810 833
#
# sihl=0.21020895401312867
# calin=233.75485108425815
# DB=1.7741580567939155
#
# 1vs4
# 766
# 1810 766
#
# sihl=0.24991173320456048
# calin=263.0853353845983
# DB=1.612969293182888
#
# 1vs5
# 558
# 1810 558
#
# sihl=0.4124717932280397
# calin=367.2232173771223
# DB=1.1599210677361529
#
# 2vs3
# 865
# 1810 865
#
# sihl=0.09125784039756174
# calin=86.50435313398827
# DB=3.0075848921982797
#
# 2vs4
# 798
# 1810 798
#
# sihl=0.16410180388000503
# calin=146.93604605908965
# DB=2.2312483684468174
#
# 2vs5
# 590
# 1810 590
#
# sihl=0.3143866193097625
# calin=224.47575485944432
# DB=1.4857353208394442
#
# 3vs4
# 841
# 1810 841
#
# sihl=0.11380541705836911
# calin=97.65914262238898
# DB=2.8317765406856963
#
# 3vs5
# 633
# 1810 633
#
# sihl=0.20562064549073653
# calin=112.04742155329059
# DB=2.1512890775974727
#
# 3vs5
# 566
# 1810 566
#
# ...

# %%
print("shawnee_2")
KMean_home="/home/spoudel/All_Thesis/Thesis_program/Data/shawnee/location_2/KMeans/"
passes=["cluster_predicted_pass_125.csv",
       "cluster_predicted_pass_126.csv",
       "cluster_predicted_pass_127.csv",
       "cluster_predicted_pass_128.csv",
       "cluster_predicted_pass_129.csv"]
df_KMean=pd.concat([pd.read_csv(KMean_home+"/"+x) for x in passes],ignore_index=True)
df_KMean_xy=df_KMean[["p0","p1","p2","p3","p4","p5","p6","cluster"]]
print("For Kmeans")
#1vs2
print("1vs2")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==0)|
                  (df_KMean_xy["cluster"]==1)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)


#1vs3
print("1vs3")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==0)|
                  (df_KMean_xy["cluster"]==2)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#1vs4
print("1vs4")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==0)|
                  (df_KMean_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#1vs5
print("1vs5")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==0)|
                  (df_KMean_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#2vs3
print("2vs3")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==1)|
                  (df_KMean_xy["cluster"]==2)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#2vs4
print("2vs4")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==1)|
                  (df_KMean_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#2vs5
print("2vs5")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==1)|
                  (df_KMean_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#3vs4
print("3vs4")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==2)|
                  (df_KMean_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#3vs5
print("3vs5")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==2)|
                  (df_KMean_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#4vs5
print("3vs5")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==3)|
                  (df_KMean_xy["cluster"]==4)
                 ]
print(len(df_13))

X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)
GMM_home="/home/spoudel/All_Thesis/Thesis_program/Data/shawnee/location_2/GMM"
passes=["cluster_predicted_pass_125.csv",
       "cluster_predicted_pass_126.csv",
       "cluster_predicted_pass_127.csv",
       "cluster_predicted_pass_128.csv",
       "cluster_predicted_pass_129.csv"]
df_GMM=pd.concat([pd.read_csv(GMM_home+"/"+x) for x in passes],ignore_index=True)
df_GMM_xy=df_GMM[["p0","p1","p2","p3","p4","p5","p6","cluster"]]
print("For GMM")
#1vs2
print("1vs2")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==0)|
                  (df_GMM_xy["cluster"]==1)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#1vs3
print("1vs3")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==0)|
                  (df_GMM_xy["cluster"]==2)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#1vs4
print("1vs4")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==0)|
                  (df_GMM_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#1vs5
print("1vs5")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==0)|
                  (df_GMM_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)


#2vs3
print("2vs3")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==1)|
                  (df_GMM_xy["cluster"]==2)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#2vs4
print("2vs4")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==1)|
                  (df_GMM_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#2vs5
print("2vs5")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==1)|
                  (df_GMM_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#3vs4
print("3vs4")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==2)|
                  (df_GMM_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#3vs5
print("3vs5")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==2)|
                  (df_GMM_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#4vs5
print("4vs5")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==3)|
                  (df_GMM_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)
# Out:
# shawnee_2
# For Kmeans
# 1vs2
# 520
# 1059 520
#
# sihl=0.16139672863031612
# calin=101.34701955660738
# DB=2.052846085717694
#
# 1vs3
# 535
# 1059 535
#
# sihl=0.23236977343190934
# calin=146.92622573587508
# DB=1.8028898271128215
#
# 1vs4
# 577
# 1059 577
#
# sihl=0.2917675976178165
# calin=244.6838305580898
# DB=1.4701570410456828
#
# 1vs5
# 423
# 1059 423
#
# sihl=0.4530573454571934
# calin=259.79636694225167
# DB=1.1106955871611226
#
# 2vs3
# 391
# 1059 391
#
# sihl=0.1020220527124122
# calin=45.14350336417947
# DB=2.7840948887268575
#
# 2vs4
# 433
# 1059 433
#
# sihl=0.1741262160364462
# calin=98.02724941742169
# DB=1.9417181295528911
#
# 2vs5
# 279
# 1059 279
#
# sihl=0.3552933988163646
# calin=135.39751210880982
# DB=1.356343035760679
#
# 3vs4
# 448
# 1059 448
#
# sihl=0.11724001424909758
# calin=62.33415590806215
# DB=2.5697774680053427
#
# 3vs5
# 294
# 1059 294
#
# sihl=0.23436832779157665
# calin=75.01675046475845
# DB=1.8195499692106856
#
# 3vs5
# 336
# 1059 336
#
# ...

# %%
print("Lathrope_1")
KMean_home="/home/spoudel/All_Thesis/Thesis_program/Data/lathrop/location_1/Kmeans"
passes=["cluster_predicted_pass_70.csv",
       "cluster_predicted_pass_71.csv",
       "cluster_predicted_pass_72.csv",
       "cluster_predicted_pass_73.csv",
       "cluster_predicted_pass_74.csv"]
df_KMean=pd.concat([pd.read_csv(KMean_home+"/"+x) for x in passes],ignore_index=True)
X_KMean_xy=df_KMean[["p0","p1","p2","p3","p4","p5","p6","cluster"]]
print("For Kmeans")
#1vs2
print("1vs2")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==0)|
                  (df_KMean_xy["cluster"]==1)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)


#1vs3
print("1vs3")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==0)|
                  (df_KMean_xy["cluster"]==2)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#1vs4
print("1vs4")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==0)|
                  (df_KMean_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#1vs5
print("1vs5")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==0)|
                  (df_KMean_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#2vs3
print("2vs3")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==1)|
                  (df_KMean_xy["cluster"]==2)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#2vs4
print("2vs4")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==1)|
                  (df_KMean_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#2vs5
print("2vs5")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==1)|
                  (df_KMean_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#3vs4
print("3vs4")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==2)|
                  (df_KMean_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#3vs5
print("3vs5")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==2)|
                  (df_KMean_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#4vs5
print("3vs5")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==3)|
                  (df_KMean_xy["cluster"]==4)
                 ]
print(len(df_13))

GMM_home="/home/spoudel/All_Thesis/Thesis_program/Data/lathrop/location_1/GMM/"
passes=["cluster_predicted_pass_70.csv",
       "cluster_predicted_pass_71.csv",
       "cluster_predicted_pass_72.csv",
       "cluster_predicted_pass_73.csv",
       "cluster_predicted_pass_74.csv"]
df_GMM=pd.concat([pd.read_csv(GMM_home+"/"+x) for x in passes],ignore_index=True)
df_GMM_xy=df_GMM[["p0","p1","p2","p3","p4","p5","p6","cluster"]]
print("For GMM")
#1vs2
print("1vs2")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==0)|
                  (df_GMM_xy["cluster"]==1)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#1vs3
print("1vs3")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==0)|
                  (df_GMM_xy["cluster"]==2)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#1vs4
print("1vs4")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==0)|
                  (df_GMM_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#1vs5
print("1vs5")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==0)|
                  (df_GMM_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)


#2vs3
print("2vs3")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==1)|
                  (df_GMM_xy["cluster"]==2)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#2vs4
print("2vs4")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==1)|
                  (df_GMM_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#2vs5
print("2vs5")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==1)|
                  (df_GMM_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#3vs4
print("3vs4")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==2)|
                  (df_GMM_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#3vs5
print("3vs5")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==2)|
                  (df_GMM_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#4vs5
print("4vs5")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==3)|
                  (df_GMM_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)
# Out:
# Lathrope_1
# For Kmeans
# 1vs2
# 520
# 2563 520
#
# sihl=0.16139672863031612
# calin=101.34701955660738
# DB=2.052846085717694
#
# 1vs3
# 535
# 2563 535
#
# sihl=0.23236977343190934
# calin=146.92622573587508
# DB=1.8028898271128215
#
# 1vs4
# 577
# 2563 577
#
# sihl=0.2917675976178165
# calin=244.6838305580898
# DB=1.4701570410456828
#
# 1vs5
# 423
# 2563 423
#
# sihl=0.4530573454571934
# calin=259.79636694225167
# DB=1.1106955871611226
#
# 2vs3
# 391
# 2563 391
#
# sihl=0.1020220527124122
# calin=45.14350336417947
# DB=2.7840948887268575
#
# 2vs4
# 433
# 2563 433
#
# sihl=0.1741262160364462
# calin=98.02724941742169
# DB=1.9417181295528911
#
# 2vs5
# 279
# 2563 279
#
# sihl=0.3552933988163646
# calin=135.39751210880982
# DB=1.356343035760679
#
# 3vs4
# 448
# 2563 448
#
# sihl=0.11724001424909758
# calin=62.33415590806215
# DB=2.5697774680053427
#
# 3vs5
# 294
# 2563 294
#
# sihl=0.23436832779157665
# calin=75.01675046475845
# DB=1.8195499692106856
#
# 3vs5
# 336
# For GMM
# 1vs2
# ...

# %%
print("Lathrope_2")
KMean_home="/home/spoudel/All_Thesis/Thesis_program/Data/lathrop/location_2/Kmeans"
passes=["cluster_predicted_pass_149.csv",
       "cluster_predicted_pass_150.csv",
       "cluster_predicted_pass_151.csv",
       "cluster_predicted_pass_152.csv",
       "cluster_predicted_pass_153.csv"]
df_KMean=pd.concat([pd.read_csv(KMean_home+"/"+x) for x in passes],ignore_index=True)
df_KMean_xy=df_KMean[["p0","p1","p2","p3","p4","p5","p6","cluster"]]
print("For Kmeans")
#1vs2
print("1vs2")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==0)|
                  (df_KMean_xy["cluster"]==1)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)


#1vs3
print("1vs3")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==0)|
                  (df_KMean_xy["cluster"]==2)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#1vs4
print("1vs4")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==0)|
                  (df_KMean_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#1vs5
print("1vs5")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==0)|
                  (df_KMean_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#2vs3
print("2vs3")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==1)|
                  (df_KMean_xy["cluster"]==2)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#2vs4
print("2vs4")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==1)|
                  (df_KMean_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#2vs5
print("2vs5")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==1)|
                  (df_KMean_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#3vs4
print("3vs4")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==2)|
                  (df_KMean_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#3vs5
print("3vs5")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==2)|
                  (df_KMean_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#4vs5
print("3vs5")
df_13 = df_KMean_xy[(df_KMean_xy["cluster"]==3)|
                  (df_KMean_xy["cluster"]==4)
                 ]
print(len(df_13))

GMM_home="/home/spoudel/All_Thesis/Thesis_program/Data/lathrop/location_2/GMM/"
passes=["cluster_predicted_pass_149.csv",
       "cluster_predicted_pass_150.csv",
       "cluster_predicted_pass_151.csv",
       "cluster_predicted_pass_152.csv",
       "cluster_predicted_pass_153.csv"]
df_GMM=pd.concat([pd.read_csv(GMM_home+"/"+x) for x in passes],ignore_index=True)
df_GMM_xy=df_GMM[["p0","p1","p2","p3","p4","p5","p6","cluster"]]
print("For GMM")
#1vs2
print("1vs2")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==0)|
                  (df_GMM_xy["cluster"]==1)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#1vs3
print("1vs3")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==0)|
                  (df_GMM_xy["cluster"]==2)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#1vs4
print("1vs4")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==0)|
                  (df_GMM_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#1vs5
print("1vs5")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==0)|
                  (df_GMM_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)


#2vs3
print("2vs3")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==1)|
                  (df_GMM_xy["cluster"]==2)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#2vs4
print("2vs4")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==1)|
                  (df_GMM_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#2vs5
print("2vs5")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==1)|
                  (df_GMM_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#3vs4
print("3vs4")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==2)|
                  (df_GMM_xy["cluster"]==3)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#3vs5
print("3vs5")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==2)|
                  (df_GMM_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)

#4vs5
print("4vs5")
df_13 = df_GMM_xy[(df_GMM_xy["cluster"]==3)|
                  (df_GMM_xy["cluster"]==4)
                 ]
print(len(df_13))
X_KMean=np.array(df_13[["p0","p1","p2","p3","p4","p5","p6"]])
y_KMean=np.array(df_13["cluster"])
print(len(df_KMean),len(y_KMean))
intrinsic_metrics(X_KMean,y_KMean)
# Out:
# Lathrope_2
# For Kmeans
# 1vs2
# 1028
# 2239 1028
#
# sihl=0.1296051117067488
# calin=163.19626986148145
# DB=2.3222234806911377
#
# 1vs3
# 958
# 2239 958
#
# sihl=0.22423997069448426
# calin=277.201547349857
# DB=1.7140319240166506
#
# 1vs4
# 1246
# 2239 1246
#
# sihl=0.21529714401740888
# calin=358.9423258635987
# DB=1.7818995766304608
#
# 1vs5
# 819
# 2239 819
#
# sihl=0.3430939470836612
# calin=335.3503478487298
# DB=1.408370098455957
#
# 2vs3
# 778
# 2239 778
#
# sihl=0.11769357610944334
# calin=103.50874333115094
# DB=2.618023622111888
#
# 2vs4
# 1066
# 2239 1066
#
# sihl=0.11422364229083662
# calin=149.44901492471166
# DB=2.4130479529333004
#
# 2vs5
# 639
# 2239 639
#
# sihl=0.3198310730900658
# calin=252.2589209095559
# DB=1.5218774807594773
#
# 3vs4
# 996
# 2239 996
#
# sihl=0.0632757441987154
# calin=79.51435620160596
# DB=3.1707785913305586
#
# 3vs5
# 569
# 2239 569
#
# sihl=0.25911968967277915
# calin=176.10032351706292
# DB=1.7299955907361009
#
# 3vs5
# 857
# For GMM
# ...

# %%
df_KMean["cluster"].unique()
# Out:
# array([4, 0, 1, 3, 2])

# %%
extrinsic measures
